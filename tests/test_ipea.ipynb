# %%
import brascraper

# %%
scraper = brascraper.scraper('IPEA')

# %%
dados = scraper.scrape(pesquisa='economia verde')
# Out:
# 2025-06-16 12:12:06,912 - IPEA - INFO - Iniciando scrape com parâmetros {'pesquisa': 'economia verde'}
# 2025-06-16 12:12:06,913 - IPEA - DEBUG - Definindo consulta
# 2025-06-16 12:12:06,914 - IPEA - DEBUG - {'palavra_chave': 'economia verde', 'tipo': '', 'assunto': '', 'autor': '', 'timeperiods': 'all', 'data-inicial': '', 'data-final': '', 'pagina': '1'}
# 2025-06-16 12:12:06,914 - IPEA - DEBUG - Definindo n_pags
# 2025-06-16 12:12:06,914 - IPEA - DEBUG - Enviando r0 (tentativa 1/3)
# 2025-06-16 12:12:07,219 - IPEA - DEBUG - <Response [200]>
# 2025-06-16 12:12:07,220 - IPEA - DEBUG - Encontrando n_pags
# 2025-06-16 12:12:07,572 - IPEA - DEBUG - Found h4 text: '29'
# 2025-06-16 12:12:07,573 - IPEA - DEBUG - Extracted number of results: 29
# 2025-06-16 12:12:07,573 - IPEA - DEBUG - Calculated pages: 3
# ...

# %%
dados
# Out:
#                                                titulo  \
# 0                     Rio+20 : desafios para o futuro
# 1   O Papel das compras públicas sustentáveis na e...
# 2      Rio+20 : priorizemos a sustentabilidade social
# 3        Economia Verde e desenvolvimento sustentável
# 4   Desenvolvimento sustentável, economia verde e ...
# 5     Desafios do desenvolvimento : v. 9, n. 72, 2012
# 6     Desafios do desenvolvimento : v. 9, n. 73, 2012
# 7                Água, recuperação pensando no futuro
# 8                       Recursos de um planeta finito
# 9   Boletim Regional, Urbano e Ambiental (BRUA) : ...
# 10  Mudanças climáticas e a necessidade de uma agr...
# 11  A China pode afetar a transição energética na ...
# 12  Boletim de Economia e Política Internacional (...
# 13              Tempo do Mundo (TM): n. 32, ago. 2023
# 14          Medidas de apoio aos combustíveis fósseis
# 15  Agenda ambiental Brasil-China como vetor auton...
# ...
